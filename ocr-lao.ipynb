# %% [markdown]
# <a href="https://colab.research.google.com/github/ntajxyooj/DeepLao/blob/main/ocr-lao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt install tesseract-ocr
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.00~git2288-10f4998a-2).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.

# %%
# !pip install pytesseract

# %%
import pytesseract
import shutil
import os
import random
try:
    from PIL import Image
except ImportError:
    import Image

# %%
from PIL import Image
import pytesseract

# %%
Image.open('/content/drive/MyDrive/lottery/la.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1650x1275 at 0x7F6C5965DF10>

# %% [markdown]
# # dowlaod data set from url:
# https://github.com/tesseract-ocr/tessdata/blob/main/lao.traineddata
#
# then upload dataset to path:
# /usr/share/tesseract-ocr/4.00/tessdata

# %%
extractedInformation = pytesseract.image_to_string(Image.open('/content/drive/MyDrive/lottery/la.jpg'),lang='lao')

# %%
print(extractedInformation)
# Out:
# 84 [0651 / ພອ61ເ
# ໂ105ໃ7 [ໄມ້ຕົ1(9
# ບໍ່ເຜັດ / ເຜັດ
# ຫນ້ອຍຫນຶງ
