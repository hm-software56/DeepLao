# %% [markdown]
# <a href="https://colab.research.google.com/github/ntajxyooj/DeepLao/blob/main/ocr_lao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Doc https://tesseract-ocr.github.io/tessdoc/

# %%
# !sudo apt install tesseract-ocr
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.00~git2288-10f4998a-2).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.

# %%
# !pip install pytesseract

# %%
import pytesseract
import shutil
import os
import random
try:
    from PIL import Image
except ImportError:
    import Image

# %%
from PIL import Image
import pytesseract

# %%
Image.open('/content/drive/MyDrive/img/test.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=767x847 at 0x7F6C5971E090>

# %% [markdown]
# # dowlaod data set from url:
# https://github.com/tesseract-ocr/tessdata/blob/main/lao.traineddata
#
# then upload dataset to path:
# /usr/share/tesseract-ocr/4.00/tessdata

# %%
extractedInformation = pytesseract.image_to_string(Image.open('/content/drive/MyDrive/img/test.jpg'),lang='lao')

# %%
print(extractedInformation)
# Out:
# ສາທາລະນະລັດ ປະຊາທິປະໄຕ ປະຊາຊົນລາວ
# ສັນຕິພາບ ເອກະລາດ ປະຊາທິປະໄຕ ເອກະພາບ ວັດທະນາຖາວອນ
#
# ມະຫາວິທະຍາໄລແທ່ງຊາດ
# .ຄະນະວິທະຍາສາດທໍາມະຊາດ ເລກທີ ຄວທ
# ນະຄອນທລວງວຽງຈັນ, ວັນທີ
# ຈ ແລ
# ໃບຮັບຮອງວິທະຍານິພົນ
# ຫົວຂໍ
# ຂຽນໂດຍ: ຊື
#
# ວິທະຍານິພົນສະບັບນີ ໄດ້ຜານການຮັບຮອງຈາກ ອາຈານທີປຶກສາ ແລະ ຄະນະກໍາມະການ
#
#  ປ້ອງກັນວິທະຍານິພົນ, ໃນຄັ່ງ ວັນທີ 9 ມັງກອນ, 2022.
#
# ທີ່ປຶກສາ: ຊື່
# ຄຄະນນະກໍາມະການປ້ອງກັນວິທະຍານິພົນ
# 1. ຮສ. ປອ. (ປະທານ).
# 2. ຮສ. ປອ (ຮອງປະທານ)
# 3. ຮສ. ປອ (ກາມະການ).
# 4. ຮສ. ປອ. (ກາມະການ).
# 5. ຮສ. ປອ. (ກາມະການ).
#
# ຄະນະບໍດີ, ຄະນະວິທະຍາສາດທໍາມະຊາດ ໄດ໋ອະນຸມັດຮັບເອົາວິທະຍານິພົນສະບັບນີເປັນສ່ວນ
# ພື່ງຂອງການສໍາເລັດການສຶກສາຕາມທຼັກສູດປະລິນຍາໂທ ວິທະຍາສາດ, ສາຂາ ຊື່ສາຂາ
#
# ຄະນະບໍດີ
